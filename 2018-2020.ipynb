# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
file = pd.read_csv('E:\\BAIUST\\Thesis Paper Documents\\Thesis Work\\Thesis_data.csv')

# %%
file
# Out:
#       Dew point Temp  Max Temperature   Min Temperature  HR  \
# 0               17.5              26.0             16.1  80
# 1               18.1              26.0             19.4  81
# 2               14.0              24.6             16.4  74
# 3               12.0              22.5             13.0  71
# 4               13.9              23.4             12.0  82
# ...              ...               ...              ...  ..
# 1091            12.8              25.6             11.5  72
# 1092            13.4              26.0             11.0  81
# 1093            13.0              25.5             10.5  78
# 1094            12.4              25.5             10.9  77
# 1095            12.5              26.7             10.5  75
#
#       Daily Maximum Rainfall  Daily Minimum Rainfall     SLP  \
# 0                        0.0                     0.0  1011.0
# 1                        0.0                     0.0  1009.6
# ...

# %%
cols=['Dew point Temp','Max Temperature ','Min Temperature','HR','Daily Maximum Rainfall','Daily Minimum Rainfall','SLP','Daily Total Rainfall','Wind_Speed','Cloud','Bright Sunshine']

# %%
pd.columns=cols

# %%
file.head()
# Out:
#    Dew point Temp  Max Temperature   Min Temperature  HR  \
# 0            17.5              26.0             16.1  80
# 1            18.1              26.0             19.4  81
# 2            14.0              24.6             16.4  74
# 3            12.0              22.5             13.0  71
# 4            13.9              23.4             12.0  82
#
#    Daily Maximum Rainfall  Daily Minimum Rainfall     SLP  \
# 0                     0.0                     0.0  1011.0
# 1                     0.0                     0.0  1009.6
# 2                     0.0                     0.0  1011.9
# 3                     0.0                     0.0  1013.5
# 4                     0.0                     0.0  1011.7
#
#    Daily Total Rainfall  Wind_Speed   Cloud  Bright Sunshine
# 0                     0          3.0      6               1.2
# 1                     0          3.0      2               1.4
# 2                     0          2.8      0               6.2
# ...

# %%
plt.figure(figsize=(10,10))

# %%
sns.heatmap(file.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))

# %%
plt.scatter(x='Dew point Temp',y='Daily Total Rainfall',data=file)

# %%
plt.scatter(x='Max Temperature ',y='Daily Total Rainfall',data=file)

# %%
plt.scatter(x='Min Temperature',y='Daily Total Rainfall',data=file)

# %%
plt.scatter(x='HR',y='Daily Total Rainfall',data=file)

# %%
plt.scatter(x='SLP',y='Daily Total Rainfall',data=file)

# %%
plt.scatter(x='Daily Maximum Rainfall',y='Daily Total Rainfall',data=file)

# %%
plt.scatter(x='Daily Minimum Rainfall',y='Daily Total Rainfall',data=file)

# %%
plt.scatter(x='Wind_Speed ',y='Daily Total Rainfall',data=file)

# %%
plt.scatter(x='Bright Sunshine ',y='Daily Total Rainfall',data=file)
