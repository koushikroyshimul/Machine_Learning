# %%
# !pip install pmdarima
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.6 MB/s eta 0:00:00
# ...

# %%
import pmdarima as pm

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import numpy as np
import datetime
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima
from statsmodels.graphics.tsaplots import plot_predict
from pylab import rcParams

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4ef7981e-e82f-4096-ba49-0ebc29d7f562" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ef7981e-e82f-4096-ba49-0ebc29d7f562">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('FinalDataset.csv')

# %%
df.head(10)
# Out:
#          Date  Rainfall  Humidity  Cloud  Dry_bulb  Min_Temp  Pressure  \
# 0  01/01/1995         0        69      0      19.2       9.9    1015.2
# 1  02/01/1995         0        70      0      15.5      11.5    1015.2
# 2  03/01/1995         0        71      0      14.2       6.0    1016.1
# 3  04/01/1995         0        72      0      15.0       6.4    1016.8
# 4  05/01/1995         0        75      0      16.1       7.0    1018.0
# 5  06/01/1995         0        73      2      18.1       8.5    1018.5
# 6  07/01/1995         0        74      2      19.4      12.0    1018.3
# 7  08/01/1995         0        75      6      20.6      11.5    1016.1
# 8  09/01/1995         0        88      7      18.1      16.3    1016.9
# 9  10/01/1995         0        82      2      18.8      15.0    1015.7
#
#    Sun Shine  Wind_Speed
# 0        6.3         0.0
# 1        8.3         0.0
# 2        8.5         0.0
# 3        8.7         0.0
# 4        8.8         6.0
# 5        5.6         4.0
# ...

# %%
print(df.columns)
# Out:
# Index(['Date', 'Rainfall', 'Humidity', 'Cloud', 'Dry_bulb', 'Min_Temp',
#        'Pressure', 'Sun Shine', 'Wind_Speed'],
#       dtype='object')

# %%
def plot_df(df, x, y, clr="", ylabel="", title="S & P 500", xlabel='Date', dpi=100):
    plt.figure(figsize=(15, 4), dpi=dpi)
    plt.plot(x, y, color=clr)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
df['Date'] = pd.to_datetime(df['Date'])
plot_df(df, x=df['Date'], y=df['Rainfall'], clr="blue", ylabel='Rainfall', title='Figure 1')

# %%
def plot_df(df, x, y, clr="", ylabel="", title="S & P 500", xlabel='Date', dpi=100):
    plt.figure(figsize=(15, 4), dpi=dpi)
    plt.plot(x, y, color=clr)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
df['Date'] = pd.to_datetime(df['Date'])
plot_df(df, x=df['Date'], y=df['Humidity'], clr="blue", ylabel='Humidity', title='Figure 2')

# %%
def plot_df(df, x, y, clr="", ylabel="", title="S & P 500", xlabel='Date', dpi=100):
    plt.figure(figsize=(15, 4), dpi=dpi)
    plt.plot(x, y, color=clr)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
df['Date'] = pd.to_datetime(df['Date'])
plot_df(df, x=df['Date'], y=df['Cloud'], clr="blue", ylabel='Cloud', title='Figure 3')

# %%
def plot_df(df, x, y, clr="", ylabel="", title="S & P 500", xlabel='Date', dpi=100):
    plt.figure(figsize=(15, 4), dpi=dpi)
    plt.plot(x, y, color=clr)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
df['Date'] = pd.to_datetime(df['Date'])
plot_df(df, x=df['Date'], y=df['Dry_bulb'], clr="blue", ylabel='Dry_bulb', title='Figure 4')

# %%
def plot_df(df, x, y, clr="", ylabel="", title="S & P 500", xlabel='Date', dpi=100):
    plt.figure(figsize=(15, 4), dpi=dpi)
    plt.plot(x, y, color=clr)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
df['Date'] = pd.to_datetime(df['Date'])
plot_df(df, x=df['Date'], y=df['Min_Temp'], clr="blue", ylabel='Min_Temp', title='Figure 5')

# %%
def plot_df(df, x, y, clr="", ylabel="", title="S & P 500", xlabel='Date', dpi=100):
    plt.figure(figsize=(15, 4), dpi=dpi)
    plt.plot(x, y, color=clr)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
df['Date'] = pd.to_datetime(df['Date'])
plot_df(df, x=df['Date'], y=df['Pressure'], clr="blue", ylabel='Pressure', title='Figure 6')

# %%
def plot_df(df, x, y, clr="", ylabel="", title="S & P 500", xlabel='Date', dpi=100):
    plt.figure(figsize=(15, 4), dpi=dpi)
    plt.plot(x, y, color=clr)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
df['Date'] = pd.to_datetime(df['Date'])
plot_df(df, x=df['Date'], y=df['Sun Shine'], clr="blue", ylabel='Sun Shine', title='Figure 7')

# %%
def plot_df(df, x, y, clr="", ylabel="", title="S & P 500", xlabel='Date', dpi=100):
    plt.figure(figsize=(15, 4), dpi=dpi)
    plt.plot(x, y, color=clr)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
df['Date'] = pd.to_datetime(df['Date'])
plot_df(df, x=df['Date'], y=df['Wind_Speed'], clr="blue", ylabel='Wind_Speed', title='Figure 8')

# %%
def test_stationarity(timeseries):
  rolmean = timeseries.rolling(12).mean()
  rolstd = timeseries.rolling(12).std()

# %%
#Plot rolling statistics:
plt.plot(timeseries, color='blue',label='Original')
plt.plot(rolmean, color='red', label='Rolling Mean')
plt.plot(rolstd, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean and Standard Deviation')
plt.show(block=False)
print("Results of dickey fuller test")
adft = adfuller(timeseries,autolag='AIC')
# Out:
# Results of dickey fuller test

# %%
output = pd.Series(adft[0:4], index=['Test Statistics', 'p-value', 'No. of lags used', 'Number of observations used'])
for key, values in adft[4].items():
    output[f'critical value ({key})'] = values
print(output)
if output[1] <= 0.05:
    print("Data is stationary")
else:
    print("Data is non-stationary ")
# Out:
# Test Statistics               -9.204895e+00
# p-value                        1.956900e-15
# No. of lags used               3.800000e+01
# Number of observations used    9.458000e+03
# critical value (1%)           -3.431042e+00
# critical value (5%)           -2.861846e+00
# critical value (10%)          -2.566933e+00
# dtype: float64
# Data is stationary
